# %% [markdown]
# # Feature Engineering
#
# Creates derived features, encodes categoricals, scales numericals, and checks VIF.

# %%
import sys

sys.path.insert(0, "..")

# %% [markdown]
# ## Run feature engineering pipeline

# %%
from src.features.engineer import main as feat_main
import sys

sys.argv = ["engineer"]
feat_main()

# %% [markdown]
# ## Feature catalog

# %%
from pathlib import Path

print(Path("../data/processed/feature_catalog.md").read_text())
