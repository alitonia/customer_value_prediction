# %% [markdown]
# # Model Training & Evaluation
#
# Trains linear and tree-based models, evaluates metrics, and serializes the best model.

# %%
import sys

sys.path.insert(0, "..")

# %% [markdown]
# ## Train all models

# %%
from src.models.train import main as train_main

train_main()

# %% [markdown]
# ## Evaluation report

# %%
from pathlib import Path

print(Path("../data/processed/model_evaluation.md").read_text())
